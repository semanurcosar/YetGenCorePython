# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import time

def vki_hesaplama(kilo,boy):

    vki = kilo/(boy**2)
    
    return round(vki,1)

def deger_araligi(vki):

    if vki<18.5:
        return "zayıf"
    elif vki<=24.9:
        return "Normal Kilolu"
    elif vki<=29.9:
        return "Fazla Kilolu"
    elif vki<=39.9:
        return "Obez"
    elif vki>40 :
        return "İleri Derecede Obez"
    
def cikti_olustur(isim,yas,kilo,boy,vki,deger):

    kayit_tarihi = time.ctime(time.time())

    t1 = f"kullanici kaydi {isim}\n"

    t2 = f"kullanicinin yas, kilo, boy bilgisi {yas}, {kilo}, {boy}\n"

    t3 = f"kullanicinin vücut kitle indexi {vki}\n"

    t4 = f"değer araligi {deger}\n"

    t5 = f"olusturma tarihi: {kayit_tarihi}\n"

    output = t1 + t2 + t3 + t4 + t5 

    return output

def main():

    giris_sayisi = int(input("kaç veri gireceksiniz:"))

    for i in range(giris_sayisi):
         print(f"kullanici kaydi {i+1}")
         isim = input("isim soyisim:")

         yas = int(input("yas:"))

         kilo = float(input("kilo kg cinsinden:"))

         boy = float(input("boy m cinsinden:"))

         vki = vki_hesaplama(kilo,boy)

         deger = deger_araligi(vki) 

         output = cikti_olustur(isim,yas,kilo,boy,vki,deger)   

         with open ("saglik.txt","a",encoding="utf-8") as file:
             file.write(output)
             file.write("*"*20)
             file.write("\n")
             print("kullanici kaydedildi")

    print("Veriler sağlik.txt dosyasina kaydedildi.\n")
main()
# Out:
# kullanici kaydi 1
# kullanici kaydedildi
# kullanici kaydi 2
# kullanici kaydedildi
# kullanici kaydi 3
# kullanici kaydedildi
# Veriler sağlik.txt dosyasina kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import time

menu = {
    "elma": 0.25 ,
    "armut": 0.50 ,
    "uzum": 2.5,
    "çilek": 3. ,
    "muz": 5. ,
    "kavun":6.5  ,
    "karpuz":5.5  ,
}

print("Elmanin fiyati : {}".format(menu["elma"]))
print("Kavunun fiyati : {}".format(menu["kavun"]))

def display_menu():

    print("--------YETBAR MENU---------")

    for item in list(menu.keys()):
         
        print(f"{item.upper():<10}:{menu[item]} TL")

def tek_urun_fiyatini_hesaplama( urun , adet):                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
    
    assert adet>=0 , "urun adedi 0 ve 0'dan küçük olamaz."
    
    if urun not in list(menu.keys()):
        return None
    
    else:
      
        return menu[urun] * adet
    
def satin_alma():
   
    display_menu()

    print("Lütfen satın almak isteğiniz ürünü giriniz.Çikmak için '0'i tuşlayiniz ")

    satin_alinan_urunler = []
    satin_alma_adedi = []

    son_fiyat = 0

    while 1:
        eklenecek_urun= input("Hangi urunden eklemek istiyorsun?")
        if eklenecek_urun == "0":
            print("Fiş kaydediliyor")
            break
   
        ekleme_adedi = int(input("Kaç adet eklemek istiyorsun?"))

        fiyat = tek_urun_fiyatini_hesaplama(eklenecek_urun,ekleme_adedi)

        if fiyat is None:
            print("Yanliş bir giriş yaptiniz, urun eklenemedi. ")
        else:
            print(f"Satın alma ücreti:{fiyat}.\n Satin almayi onaylamak için 'y' iptal etmek için 'n' giriniz.")

            check = input("Satin almayi onayliyor musunuz:")

            if check == "y":
                print("Satin alim onaylandi.")
                print("-"*40)

                son_fiyat += fiyat

                satin_alinan_urunler.append(eklenecek_urun)

                satin_alma_adedi.append(ekleme_adedi)
                print(f"Ara toplam: {son_fiyat}")
            elif check == "n":
                print("Satın alma işlemi iptal edildi.")
                print("-"*40)
    return  son_fiyat, satin_alinan_urunler, satin_alma_adedi       

def main():

    print("YetBar'a hoşgeldiiniz !\nMenüyü görüntülemek için '1'e, smoothie yapmak için lütfen '2'e basiniz. Çikmak için '0' giriniz.")

    program = None

    while 1:
        program = int(input("Tercihiniz:"))

        if program < 0 or program > 2:
            print("Yanlış bir tercih yaptiniz")
        elif program == 0:
            print("Çikiş yapiliyor... \nSağlikli günler dileriz.")
            break
        elif program == 1:
            display_menu()
        elif program == 2:
            satin_alma_ucreti, satin_alinan_urunler, satin_alma_adedi = satin_alma()  
            
            with open("kasa.txt","a",) as file:
                file.write(str(time.ctime(time.time())))
                file.write("\n")
                file.write(','.join(map(str, satin_alinan_urunler)))
                file.write("\n")
                file.write(','.join(map(str, satin_alma_adedi)))
                file.write("\n")
                file.write(f"Toplam: {satin_alma_ucreti}")
                file.write("\n")
                file.write("*"*20)
                file.write("\n")
            
            cikis_kontrol = input("Başka bir işlem yapmak istiyor musunuz?(evet-hayir)")

            if cikis_kontrol == "evet":
                pass
            else:
                print("\nTEŞEKKÜRLER")
                break


main()
# Out:
# Elmanin fiyati : 0.25
# Kavunun fiyati : 6.5
# YetBar'a hoşgeldiiniz !
# Menüyü görüntülemek için '1'e, smoothie yapmak için lütfen '2'e basiniz. Çikmak için '0' giriniz.
# --------YETBAR MENU---------
# ELMA      :0.25 TL
# ARMUT     :0.5 TL
# UZUM      :2.5 TL
# ÇILEK     :3.0 TL
# MUZ       :5.0 TL
# KAVUN     :6.5 TL
# KARPUZ    :5.5 TL
# Lütfen satın almak isteğiniz ürünü giriniz.Çikmak için '0'i tuşlayiniz
# Satın alma ücreti:13.0.
#  Satin almayi onaylamak için 'y' iptal etmek için 'n' giriniz.
# Satin alim onaylandi.
# ----------------------------------------
# Ara toplam: 13.0
# Fiş kaydediliyor
#
# TEŞEKKÜRLER
